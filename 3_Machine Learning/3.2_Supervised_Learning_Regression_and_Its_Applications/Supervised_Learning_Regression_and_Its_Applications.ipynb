# %% [markdown]
# # Supervised_Learning_Regression_and_Its_Applications

# %% [markdown]
# ## Regression

# %% [markdown]
# ![](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ML/updated/Lesson_04/Linear.png)

# %% [markdown]
# __`Independent variables(inputs)`__
#
# * a variable that is used to explain or predict another variable.
# * These variables influence the prediction, but they are not the value being predicted.
# * An independent variable is a predictor or input variable used to estimate the outcome in a regression model.

# %% [markdown]
# __`Dependent variable (output)`__
#
# * the variable model is trying to predict or explain. Its value depends on the independent variables.
# * A dependent variable is the outcome or target variable whose value is predicted using the independent variables.

# %% [markdown]
# ### Application of Regression

# %% [markdown]
# 1. Oil and Gas Industry: Various types of data are collected in the oil and gas industry from the surface and subsurface to understand production and sale processes. Linear and non-linear regression models forecast global oil production.
#
# __Dependent Variable:__ Global oil production (what the model is trying to predict.)
#
# __Inependent Variable:__ factors used to predict global oil production (Surface data, equipment performance, drilling activity, Subsurface data, reservoir pressure, rock properties, Historical production data, Oil prices, Number of active wells)
#
# 2. Marketing: In marketing, linear regression helps analyze the effectiveness of advertising campaigns, predict sales based on marketing spend, and segment customers based on demographic data.
#
# __Dependent Variable:__ SALES
#
# __Inependent Variable:__ factors used to predict the outcome such as Marketing spend / advertising spend
#
# 3. Retail: Linear regression is utilized in retail for demand forecasting, inventory management, pricing optimization, and customer analytics.
#
# __Dependent Variable:__ forecasting. Product demand (how many items will be sold)
#
# __Inependent Variable:__ factors used to predict demand.(Product price, Promotions or discounts, Season or time of year, Historical sales data, Store location)
#
# 4. Healthcare: Linear regression is applied in healthcare for predicting patient outcomes, analyzing the relationship between medical variables and disease progression, and planning healthcare resources.
#
# __Dependent Variable:__ Patient outcome (Recovery time, Disease progression level, Risk of complications, Length of hospital stay)
#
# __Independent Variable:__ the medical factors used to make the prediction (Age, Blood pressure, Cholesterol level, Medical test results, Treatment type)
#
# 5. Real Estate: In the real estate industry, linear regression predicts property prices based on factors such as location, size, amenities, and economic indicators.
#
# __Dependent Variable:__
#
# __Independent Variable:__

# %% [markdown]
# ### `Types of Regression`

# %% [markdown]
# > The target variable is the value the model is trying to predict.

# %% [markdown]
# #### __`Linear Regression`__
#
# Linear regression finds a straight-line relationship between the dependent variable and one or more independent variables.
#
# * It predicts a continuous dependent variable based on one or more independent variables.
# * It uses the least squares criterion to estimate the coefficients of the regression equation..
# * It can be applied only if there is a linear relationship between the variables.

# %% [markdown]
# __There are two types of linear regression:__
#
# * __Simple linear regression:__
#   models the relationship between one independent variable and the dependent variable as a   straight line.
#   the equation for simple linear regression: 𝑦=𝛽0+𝛽1𝑥
#
#   * 𝑦  is the dependent variable
#   * 𝑥  is the independent variable
#   * β0  is the intercept
#   * β1  is the slope
#
# <br>
#
# * __Multiple linear regression__
#   Multiple linear regression models the relationship between two or more independent
#   variables/predictors/features and the dependent variable as a straight line.
#
#   The equation for Multiple Linear Regression: 𝑦=𝛽0+𝛽1𝑥1+𝛽2𝑥2+…+𝛽𝑛𝑥𝑛
#
#   * 𝑥1,𝑥2,…,𝑥𝑛  are the predictor variables,
#   * 𝛽1,𝛽2,…,𝛽𝑛  are the coefficients for each predictor.

# %% [markdown]
# __Non-Linear Regression__
#
# Non-linear regression finds a relationship between the dependent variable and independent variables using a curve or a more complex shape.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("datasets/tvmarketing.csv")

# %% [markdown]
# __The following command provides details about the dataset__

# %%
# Display a summary of the DataFrame, including the column names, non-null count, and data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %% [markdown]
# __Observation:__
#
# __There are no null objects.__

# %% [markdown]
# >__Fit the Linear Regression Model__
#
#  >>(preparing the data so a linear regression model can learn the relationship between the two variables)
#
# >__Define the features (x) and the target variables.__
# >> seperating the model into two parts feautures (x: indepependent variables : TV)
# >> and a target variable (y: dependent variable : Sales)
#
#
#
# >X is assigned to all the rows in the first column of the dataset.
# >> take the first column of the dataset because it contains the variable used to predict something.
#
# >y is assigned to all the rows of the second column of the same dataset.
#
#
# | Hours Studied | Exam Score |
# | ------------- | ---------- |
# | 1             | 50         |
# | 2             | 55         |
# | 3             | 65         |
# | 4             | 70         |
#
# in the code:
# This means:
#
# : = all rows
#
# 0 = first column
#
# This means:
# : = all rows
#
# 1 = second column

# %%
# Extract the feature(s) from the DataFrame
X=data.iloc[:,0:1].values
# Extract the target variable from the DataFrame
y=data.iloc[:,1].values

# %% [markdown]
# __A train-test split is a step in machine learning where the dataset is divided into two parts so we can train a model and then test how well it works.__
#
# ___
#
# __The test set is used after training to check how well the model performs.__
#
# __This data was not used during training, so it shows whether the model can predict new data correctly.__

# %% [markdown]
# Perform train-test split
#
# Train-test split is a technique in machine learning used to evaluate a model's performance by dividing the data into two parts: a training set and a test set. The model is trained on the training set, learning patterns and parameters, and then evaluated on the test set to see how well it generalizes to new, unseen data.
#
# Note: This train-test data split will be used for other implementations as well.

# %% [markdown]
# __scikit-learn__ contains tools for:
#
# * Linear Regression
#
# * Logistic Regression
#
# * Decision Tree
#
# * Random Forest
#
# * K-Nearest Neighbors

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.13/site-packages (from scikit-learn) (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.13/site-packages (from scikit-learn) (1.17.1)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp313-cp313-macosx_10_13_x86_64.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 3.2 MB/s eta 0:00:00a 0:00:01m
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import train_test_split function from sklearn's model_selection module
from sklearn.model_selection import train_test_split

# %% [markdown]
# __Python loaded the `train_test_split` function from the machine learning library__
#
# * sklearn → the Python name for the scikit-learn library
#
# * model_selection → a module that contains tools for preparing datasets
#
# * train_test_split → the function used to divide data into training and testing sets

# %% [markdown]
# Allowed inputs in train_test_split() are lists, numpy arrays, scipy-sparse matrices or pandas dataframes. In this implementation X and y will be passed as arrays of corresponding values

# %%
# Split the dnata ito training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# This line **splits your dataset into training and testing data** so a machine learning model can be trained and then evaluated.
#
# The function comes from **scikit-learn** and is commonly used before training models such as **Linear Regression**.
#
# ---
#
# ## What each part means
#
# ### 1. `train_test_split(X, y, ...)`
#
# This function **divides the dataset into two groups**:
#
# * **Training data** → used to teach the model
# * **Testing data** → used to evaluate the model
#
# ---
#
# ### 2. `X`
#
# These are the **features (independent variables)**.
#
# In your dataset example:
#
# * **X = TV advertising spending**
#
# ---
#
# ### 3. `y`
#
# This is the **target variable (dependent variable)**.
#
# In your dataset:
#
# * **y = Sales**
#
# ---
#
# ### 4. `test_size = 0.3`
#
# This means:
#
# * **30% of the data → testing set**
# * **70% of the data → training set**
#
# Since your dataset has **200 rows**:
#
# | Dataset Part  | Size     |
# | ------------- | -------- |
# | Training data | 140 rows |
# | Testing data  | 60 rows  |
#
# ---
#
# ### 5. `random_state = 42`
#
# This controls **how the data is randomly split**.
#
# * It ensures the **same split happens every time the code runs**.
# * This makes results **reproducible**.
#
# ---
#
# ### 6. Output variables
#
# The function returns **four datasets**:
#
# | Variable    | Meaning                |
# | ----------- | ---------------------- |
# | **X_train** | training features      |
# | **X_test**  | testing features       |
# | **y_train** | training target values |
# | **y_test**  | testing target values  |
#
# So Python assigns the outputs like this:
#
# ```text
# X_train → features for training
# X_test → features for testing
# y_train → correct answers for training
# y_test → correct answers for testing
# ```
#
# ---

# %% [markdown]
# This code splits the dataset (X, y) into a training set (70%) and a test set (30%).
#
# As you may have noticed, we’ve been setting the random_state parameter in our examples. This parameter is the seed used by the random number generator. Setting a seed ensures that the splits you generate are reproducible. If you don’t set a seed, you might get different splits every time you run the code, which can make your results hard to replicate. it

# %% [markdown]
# First, let us see if linear regression works on this data.
# From sklearn.linear_model, import the linear regression function.
# Assign LinearRegression() to the variable lin_reg.
# Next, fit the data on the training data X_train and y_train.

# %%
# Import the LinearRegression class from scikit-learn's linear_model module
from sklearn.linear_model import LinearRegression
# Create an instance of the LinearRegression class
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# | Step | What happened                             |
# | ---- | ----------------------------------------- |
# | 1    | Imported the Linear Regression model      |
# | 2    | Created a model object                    |
# | 3    | Trained the model using the training data |
#
# | Parameter         | Meaning                                          |
# | ----------------- | ------------------------------------------------ |
# | **fit_intercept** | Whether the model calculates the intercept       |
# | **copy_X**        | Whether the input data is copied before training |
# | **tol**           | Precision level for optimization                 |
# | **n_jobs**        | Number of CPU cores used                         |
# | **positive**      | Whether coefficients must be positive            |

# %%
def viz_linear():
    plt.scatter(X_test, y_test, color='green')  # X_test should represent TV expenses
    plt.plot(X_train, lin_reg.predict(X_train), color='blue')  # X_train is TV expenses, predicted values are Sales
    plt.title('Linear Regression Model (Test set)')
    plt.xlabel('TV')  # Independent variable (TV)
    plt.ylabel('Sales')  # Dependent variable (Sales)
    plt.show()

# %%
viz_linear()

# %% [markdown]
# The plot shows a positive linear relationship between Sales and TV, where the blue regression line indicates the model's predictions. The green data points are generally close to the line, suggesting the model fits the data reasonably well, though some variability exists.
# ___

# %% [markdown]
# Overfitting and Underfitting
# When developing machine learning models, achieving the right balance between complexity and simplicity is crucial. This balance is covered in the concepts of overfitting and underfitting.
#
# Overfitting
#
# Overfitting occurs when a model learns the noise and details in the training data too well to the extent that it negatively impacts its performance on new unseen data.
# Sign: High accuracy on training data but poor accuracy on test data.
# Cause: Model is too complex (too many parameters).
# Underfitting
#
# Underfitting happens when a model is too simple to capture the underlying pattern of the data.
# Sign: Poor accuracy on both training and test data.
# Cause: Model is too simple (too few parameters).
# Bias-Variance Tradeoff
#
# Bias: Error due to overly simplistic assumptions in the learning algorithm. High bias can cause underfitting.
# Variance: Error due to excessive complexity in the learning algorithm. High variance can cause overfitting.
# Tradeoff
#
# Low Bias & High Variance: Model fits the training data very well but may fail to generalize (overfitting).
# High Bias & Low Variance: Model does not fit the training data well and misses the underlying trend (underfitting).
# Optimal Tradeoff: Finding a balance where the model performs well on both training and test data, minimizing overall error.
# Understanding and managing the bias-variance tradeoff is key to building models that generalize well to unseen data.
#
# Let's look at how to check for overfitting or underfitting of the model

# %%
# Import necessary libraries for performance metrics
from sklearn.metrics import mean_squared_error, r2_score

# Predicting for the training set
y_train_pred = lin_reg.predict(X_train)

# Predicting for the test set
y_test_pred = lin_reg.predict(X_test)

mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

# Print the metrics
print("Training Set Mean Squared Error:", mse_train)
print("Test Set Mean Squared Error:", mse_test)
print("Training Set R² Score:", r2_train)
print("Test Set R² Score:", r2_test)
print("------------------------------------------")
# Check for overfitting or underfitting
if mse_train < mse_test or r2_train > r2_test:
    if abs(r2_train - r2_test) > 0.1:
        print("Model may be overfitting to the training data.")
    else:
        print("Model performs reasonably well but check for slight overfitting.")
elif mse_train > mse_test and r2_train < r2_test:
    print("Model may be underfitting, consider increasing model complexity.")
else:
    print("Model has a balanced fit on both training and testing datasets.")
# Out:
# Training Set Mean Squared Error: 11.189103289351678
# Test Set Mean Squared Error: 8.970991242413616
# Training Set R² Score: 0.5736021199591974
# Test Set R² Score: 0.6714477229302764
# ------------------------------------------
# Model may be underfitting, consider increasing model complexity.

# %% [markdown]
# Observation
#
# Mean Squared Error (MSE) and R-squared (R²) values are calculated for both training and test datasets.
#
# MSE measures the average of the squares of the errors, that is, the average squared difference between the estimated values and the actual value.
# R² provides an indication of goodness of fit and therefore a measure of how well unseen samples are likely to be predicted by the model
# Overfitting: The model performs well on the training data but poorly on the test data (higher R² on training or lower MSE on training compared to testing).
#
# Underfitting: The model performs poorly on both training and test data, or better on the test data compared to the training data, which could suggest that the model is too simple.
#
# We'll discuss more about MSE, R² and various other performance metrices, further in the lesson
