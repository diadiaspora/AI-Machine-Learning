# %% [markdown]
# <a href="https://colab.research.google.com/github/diadiaspora/python_practice/blob/main/notebooks/Demo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = [25, "Hello", 3.14, "Python", 100, 7.89, "AI", 42, "Data", 2.718]

# %%
my_list
# Out:
# [25, 'Hello', 3.14, 'Python', 100, 7.89, 'AI', 42, 'Data', 2.718]

# %%
positive_indexing = [my_list[0], my_list[3], my_list[6]]

# %%
print(positive_indexing)
# Out:
# [25, 'Python', 'AI']

# %%
negative_indexing = [my_list[-1], my_list[-4], my_list[-7]]

# %%
print(negative_indexing)
# Out:
# [2.718, 'AI', 'Python']

# %%
sublist = my_list[2:7]
print(sublist)
# Out:
# [3.14, 'Python', 100, 7.89, 'AI']

# %%
my_list = [25, "Hello", 3.14, "Python", 100, 7.89, "AI", 42, "Data", 2.718]
print(my_list)
# Out:
# [25, 'Hello', 3.14, 'Python', 100, 7.89, 'AI', 42, 'Data', 2.718]

# %%
my_list.append("New Element")

# %%
print(my_list)
# Out:
# [25, 'Hello', 3.14, 'Python', 100, 7.89, 'AI', 42, 'Data', 2.718, 'New Element', 'New Element']

# %%
my_list.remove(100)
print(my_list)
# Out:
# [25, 'Hello', 3.14, 'Python', 7.89, 'AI', 42, 'Data', 2.718, 'New Element', 'New Element']

# %% [markdown]
# __Do Over__

# %%
my_list = [25, "Hello", 3.14, "Python", 100, 7.89, "AI", 42, "Data", 2.718]

# %%
positive_indexing = [my_list[0], my_list[3], my_list[6]]
print(positive_indexing)
# Out:
# [25, 'Python', 'AI']

# %%
negative_indexing = [my_list[-1], my_list[-4], my_list[-7]]
print(negative_indexing)
# Out:
# [2.718, 'AI', 'Python']

# %%
sublist = my_list[2:7]
print(sublist)
# Out:
# [3.14, 'Python', 100, 7.89, 'AI']

# %%
my_list = [25, "Hello", 3.14, "Python", 100, 7.89, "AI", 42, "Data", 2.718]
print(my_list)
my_list.append("New Element")
print(my_list)
my_list.remove(100)
print(my_list)
# Out:
# [25, 'Hello', 3.14, 'Python', 100, 7.89, 'AI', 42, 'Data', 2.718]
# [25, 'Hello', 3.14, 'Python', 100, 7.89, 'AI', 42, 'Data', 2.718, 'New Element']
# [25, 'Hello', 3.14, 'Python', 7.89, 'AI', 42, 'Data', 2.718, 'New Element']
