# %%
my_set = {10, "Python", 3.14, "AI", 42, "Data", 7.89}

# %%
print(my_set)
# Out:
# {'AI', 'Data', 3.14, 42, 7.89, 10, 'Python'}

# %%
my_set.add("Machine Learning")

# %%
print(my_set)
# Out:
# {'AI', 'Data', 'Machine Learning', 3.14, 42, 7.89, 10, 'Python'}

# %%
my_set.remove(42)

# %%
print(my_set)
# Out:
# {'AI', 'Data', 'Machine Learning', 3.14, 7.89, 10, 'Python'}

# %%
my_set.add("Python")

# %%
print(my_set)
# Out:
# {'AI', 'Data', 'Machine Learning', 3.14, 7.89, 10, 'Python'}

# %%
another_set = {3.14, "AI", "Deep Learning", 99, "Data"}

# %%
union_set = my_set.union(another_set)

# %%
print(union_set)
# Out:
# {'AI', 'Machine Learning', 3.14, 99, 7.89, 10, 'Python', 'Data', 'Deep Learning'}

# %%
intersection_set = my_set.intersection(another_set)

# %%
print(intersection_set)
# Out:
# {'AI', 'Data', 3.14}

# %%
difference_set = my_set.difference(another_set)

# %%
print(difference_set)
# Out:
# {'Machine Learning', 10, 'Python', 7.89}

# %%
duplicate_list = [10, "Python", 3.14, "AI", 10, "Python", "AI", 42]

# %%
print(duplicate_list)
# Out:
# [10, 'Python', 3.14, 'AI', 10, 'Python', 'AI', 42]

# %%
unique_list = list(set(duplicate_list))

# %%
print(unique_list)
# Out:
# ['AI', 3.14, 10, 42, 'Python']

# %%
set_as_list = list(my_set)

# %%
print(set_as_list)
# Out:
# ['AI', 'Data', 'Machine Learning', 3.14, 7.89, 10, 'Python']

# %%
set_as_tuple = tuple(my_set)

# %%
print(set_as_tuple)
# Out:
# ('AI', 'Data', 'Machine Learning', 3.14, 7.89, 10, 'Python')

# %% [markdown]
# __Do Over__

# %%
my_set = {10, "Python", 3.14, "AI", 42, "Data", 7.89}
print(my_set)
# Out:
# {3.14, 42, 'Python', 'Data', 7.89, 'AI', 10}

# %%
my_set.add("Machine Learning")  # Adding a new element
print(my_set)
my_set.remove(42)  # Removing an existing element
print(my_set)
# Out:
# {3.14, 42, 'Python', 'Data', 7.89, 'AI', 'Machine Learning', 10}
# {3.14, 'Python', 'Data', 7.89, 'AI', 'Machine Learning', 10}

# %%
another_set = {3.14, "AI", "Deep Learning", 99, "Data"}

union_set = my_set.union(another_set)  # Combines elements from both sets
intersection_set = my_set.intersection(another_set)  # Common elements
difference_set = my_set.difference(another_set)  # Elements in my_set but not in another_set

print(union_set)
print(intersection_set)
print(difference_set)
# Out:
# {3.14, 'Machine Learning', 99, 'Data', 7.89, 'AI', 10, 'Python', 'Deep Learning'}
# {'AI', 3.14, 'Data'}
# {10, 'Python', 'Machine Learning', 7.89}

# %%
duplicate_list = [10, "Python", 3.14, "AI", 10, "Python", "AI", 42]
print(duplicate_list)
unique_list = list(set(duplicate_list))  # Converts the list to a set and back to a list to remove duplicates
print(unique_list)
# Out:
# [10, 'Python', 3.14, 'AI', 10, 'Python', 'AI', 42]
# [3.14, 'AI', 10, 42, 'Python']

# %%
set_as_list = list(my_set)  # Set converted to a list (unordered)
set_as_tuple = tuple(my_set)  # Set converted to a tuple (unordered but immutable)
print(set_as_list)
print(set_as_tuple)
# Out:
# [3.14, 'Python', 'Data', 7.89, 'AI', 'Machine Learning', 10]
# (3.14, 'Python', 'Data', 7.89, 'AI', 'Machine Learning', 10)
